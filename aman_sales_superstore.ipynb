# %% [markdown]
# ## SUPER MARKET SALES

# %% [markdown]
# ### Introduction:-
#                   This is a supermarket dataset of both males and females. The dataset is collected from 3 different cities  (mandalay,naypyitaw,yangon).
#       * it shows there spending patterns across differnt product lines,
#       * it also shows there preffered methods of payment.
#       * gross income of all individuals.
#       * total sales of the supermarket.
#       * quantity purchased each time.
#       * ratings given after each purchase.

# %%
## Importing the libraries

import os
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import datetime

# %%
market = pd.read_csv(R"C:\Users\Administrator\Downloads\supermarket_sales (1).csv") # Reading supermarket dataset
market
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
market.head() #READING TOP 5 DATASETS.
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
market.tail() #READING LAST 5 DATASETS.
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
market.drop(['Invoice ID'],axis=1,inplace=True) #DROPPING THE COLUMN AS IT DOESN'T GIVE USEFUL INFORMATION.

# %%
market.shape #EXPLORING NUMBER OF VARIABLES AND OBSERVATIONS.
# Out:
# (1000, 16)

# %%
market.info() #CHECKING THE DATATYPE OF EACH COLUMN.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Customer type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product line             1000 non-null   object
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   object
#  10  Time                     1000 non-null   object
#  11  Payment                  1000 non-null   object
#  12  cogs                     1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
# ...

# %%
market.nunique() #CHECKING THE UNIQUE VALUES OF EACH COLUMN.
# Out:
# Branch                       3
# City                         3
# Customer type                2
# Gender                       2
# Product line                 6
# Unit price                 943
# Quantity                    10
# Tax 5%                     990
# Total                      990
# Date                        89
# Time                       506
# Payment                      3
# cogs                       990
# gross margin percentage      1
# gross income               990
# Rating                      61
# dtype: int64

# %%
market.drop(['gross margin percentage'],axis=1,inplace=True) #dropping the coulmn as it has only 1 unique value.

# %%
market.shape #EXPLORING NUMBER OF VARIABLES AND OBSERVATIONS AFTER DROPPING THE COLUMNS.
# Out:
# (1000, 15)

# %%
markets=market.isnull() #CHECKING NULL VALUES IN THE DATASET.
markets
# Out:
#      Branch   City  Customer type  Gender  Product line  Unit price  Quantity  \
# 0     False  False          False   False         False       False     False
# 1     False  False          False   False         False       False     False
# 2     False  False          False   False         False       False     False
# 3     False  False          False   False         False       False     False
# 4     False  False          False   False         False       False     False
# ..      ...    ...            ...     ...           ...         ...       ...
# 995   False  False          False   False         False       False     False
# 996   False  False          False   False         False       False     False
# 997   False  False          False   False         False       False     False
# 998   False  False          False   False         False       False     False
# 999   False  False          False   False         False       False     False
#
# ...

# %%
markets.sum() #suming the null values
# Out:
# Branch           0
# City             0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Tax 5%           0
# Total            0
# Date             0
# Time             0
# Payment          0
# cogs             0
# gross income     0
# Rating           0
# dtype: int64

# %%
market.drop_duplicates() #dropping duplicates values
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
market["Date"]=pd.to_datetime(market["Date"])  #converting datatype of column "Date"
market["Date"]
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
market["Time"]=pd.to_datetime(market["Time"])  #converting datatype of column "Time"
market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Branch         1000 non-null   object
#  1   City           1000 non-null   object
#  2   Customer type  1000 non-null   object
#  3   Gender         1000 non-null   object
#  4   Product line   1000 non-null   object
#  5   Unit price     1000 non-null   float64
#  6   Quantity       1000 non-null   int64
#  7   Tax 5%         1000 non-null   float64
#  8   Total          1000 non-null   float64
#  9   Date           1000 non-null   datetime64[ns]
#  10  Time           1000 non-null   datetime64[ns]
#  11  Payment        1000 non-null   object
#  12  cogs           1000 non-null   float64
#  13  gross income   1000 non-null   float64
#  14  Rating         1000 non-null   float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(6)
# memory usage: 117.3+ KB

# %%
market["year"]=market["Date"].dt.year      #separating "year" from "Date" column.
market["month"]=market["Date"].dt.month    #separating "month" from "Date" column.
market["day"]=market["Date"].dt.day        #separating "day" from "Date" column.
market["hour"]=market["Time"].dt.hour      #separating "hour" from "Time" column.
market.head(5)
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%  Total_sales       Date                Time      Payment  \
# 0         7  26.1415     548.9715 2019-01-05 2022-02-22 13:08:00      Ewallet
# 1         5   3.8200      80.2200 2019-03-08 2022-02-22 10:29:00         Cash
# 2         7  16.2155     340.5255 2019-03-03 2022-02-22 13:23:00  Credit card
# 3         8  23.2880     489.0480 2019-01-27 2022-02-22 20:33:00      Ewallet
# 4         7  30.2085     634.3785 2019-02-08 2022-02-22 10:37:00      Ewallet
#
# ...

# %%
sns.countplot(x ='Gender', data = market)  #checking number of counts of males and females,to cross-check bias scienario. 
plt.show()

# %% [markdown]
# ### Q1)-Is your supermarket more popular with males or females?
# ### Q2)-What does the customer rating look like and can you also comment on its skewness?

# %%
sns.boxplot(x='Gender',y='Rating',data=market,showmeans=True)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Rating'>

# %% [markdown]
# #### Result:- Based on the above graph,it is found that supermarket is equally popular with both males and females,since both have rated it 7 on average.

# %% [markdown]
# #### Result:- Based on the above boxplot it is found that customer rating doesn't have any outliers and the data is normally distributed.

# %%
market.rename(columns={'Total':'Total_sales'}) #renaming column "Total" to "Total_sales"
market.head(5)
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%  Total_sales       Date                Time      Payment  \
# 0         7  26.1415     548.9715 2019-01-05 2022-02-22 13:08:00      Ewallet
# 1         5   3.8200      80.2200 2019-03-08 2022-02-22 10:29:00         Cash
# 2         7  16.2155     340.5255 2019-03-03 2022-02-22 13:23:00  Credit card
# 3         8  23.2880     489.0480 2019-01-27 2022-02-22 20:33:00      Ewallet
# 4         7  30.2085     634.3785 2019-02-08 2022-02-22 10:37:00      Ewallet
#
# ...

# %% [markdown]
# ### Q3)What can you say about the aggregate sales across the branches?

# %%
sns.set_style("whitegrid")
sns.boxplot(x='Branch',y='Total_sales',data=market,showmeans=True)
plt.xlabel('Branch')
plt.ylabel('Total_sales')
plt.title('aggregate sales across the branches')
# Out:
# Text(0.5, 1.0, 'aggregate sales across the branches')

# %%
sns.barplot(x='Branch',y='Total_sales',data=market)
plt.xlabel('Branch')
plt.ylabel('Total_sales')
plt.title('aggregate sales across the branches')
# Out:
# Text(0.5, 1.0, 'aggregate sales across the branches')

# %% [markdown]
# #### Result:- based on the above boxplot data of branch A,B has outliers. and based on the above barplot it is found that Branch "C" has slightly higher aggregate sales as compared to branch "A" and "B".

# %% [markdown]
# ### Q4)Which is the most popular payment method used by customers?

# %%
sns.set_style("whitegrid")
sns.countplot(x ='Payment', data = market)
plt.xlabel('Payment method')
plt.title('most popular payment method')
plt.show()

# %% [markdown]
# #### Result:- Based on the above count plot it is infered that "Ewallet" and "Cash" are equally most important payment methods used by customers.

# %% [markdown]
# ### Part 3:-

# %% [markdown]
# ### Q1) Does gross income affect customer ratings?

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="Rating",y="gross income",hue="Gender",data=market)
plt.xlabel("customer ratings")
plt.ylabel("Gross income[In Lakhs]")
plt.title("relationship between gross income & ratings")
# Out:
# Text(0.5, 1.0, 'relationship between gross income & ratings')

# %% [markdown]
# #### Result:- Based on the above scatter plot, its found that customer rating is not affected by gross income,both are independant of each other.

# %% [markdown]
# ### Q2) Which is the most profitable branch?

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Branch',y='Total_sales',data=market)
plt.xlabel('Branch')
plt.ylabel('Total_sales')
plt.title('most profitable branch')
# Out:
# Text(0.5, 1.0, 'most profitable branch')

# %% [markdown]
# #### Result:- here it is found that branch "C" is the most profitable branch as compared to branch"A", "B".

# %% [markdown]
# ### Q3)How is the relationship between Gender and Gross income?

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="Gender",y="gross income",hue="City",data=market)
plt.xlabel("Gender")
plt.ylabel("Gross income[In Lakhs]")
plt.title("relationship between Gender & ratings")
# Out:
# Text(0.5, 1.0, 'relationship between Gender & ratings')

# %% [markdown]
# #### Result:- There is no  linear relationship between gender and gross income.

# %% [markdown]
# ### Q4) Time trend in gross income?

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='month',y='gross income',data=market)
plt.xlabel("month")
plt.ylabel("Gross income[In Lakhs]")
plt.title("time trend in gross income")
# Out:
# Text(0.5, 1.0, 'time trend in gross income')

# %% [markdown]
# #### Result:- based on above line graph ,month wise gross income falls moderatly.

# %%
sns.histplot(data=market['Total_sales'],kde=True)                           # checking the skewness of the column "total_sales"
plt.axvline(x=market.Total_sales.mean(),color='red',alpha=0.5,label='mean')
plt.axvline(x=market.Total_sales.median(),color='blue',ls="--",alpha=0.5,label='median')
plt.legend()

# %% [markdown]
# #### result:- the column "total_sales" is highly righy skewed.

# %% [markdown]
# ### log transformation

# %%
market['Total_sales_log']=np.log(market['Total_sales'])  #creating new column "Total_sales_log" after log transformation.

# %%
sns.distplot(market['Total_sales_log'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total_sales_log', ylabel='Density'>

# %% [markdown]
# #### Result:- after the transformation the column is now moderatly left skewed.

# %% [markdown]
# ### Q5) Which product line generates the most income?

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='Product line',y='Total_sales_log',data=market,showmeans=True)        #with log data
plt.title("product line with most income")
# Out:
# Text(0.5, 1.0, 'product line with most income')

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='Product line',y='Total_sales_log',data=market)       #with log data
plt.title('product line with most income')
# Out:
# Text(0.5, 1.0, 'product line with most income')

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='Product line',y='Total_sales',data=market)     #without log data
plt.title('product line with most income')
# Out:
# Text(0.5, 1.0, 'product line with most income')

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='Product line',y='Total_sales',data=market,showmeans=True)      #without log data
plt.title("product line with most income")
# Out:
# Text(0.5, 1.0, 'product line with most income')

# %% [markdown]
# #### Result:-  based on actual data-- "home and lifestyle" product line has given us the most income.
#               based on trensformed data-- all product line except "health & beauty" & " electronics accessories" have
#               generated same income

# %% [markdown]
# ### Q6) In which category do males & females spend more?

# %%
plt.figure(figsize=(12,5))
sns.set_style("whitegrid")
sns.countplot(x ='Product line', hue='Gender',data = market)
plt.xlabel('product category')
plt.title('spending pattern besed on product category')
plt.show()

# %% [markdown]
# #### Result:- based on the above graph, males spend more in ( health and beauty, electronics accessories, home & lifestyle categories).
# #### and females spend more in ( sports and travel, food and beverages, fashion accessories).

# %% [markdown]
# ### Q7) How many products are bought by customers?

# %%
column_name = "Quantity"
total_products_sold = market[column_name].sum()
total_products_sold
# Out:
# 5510

# %% [markdown]
# #### total products across all categories bought by customers are = 5510

# %% [markdown]
# ### Q8) Which day of the week has maximum sales?

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='day',y='Total_sales',data=market,showmeans=True)
plt.title("max. sales week_day")
# Out:
# Text(0.5, 1.0, 'max. sales week_day')

# %% [markdown]
# ### Q9) Which hour of the day is busiest?

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='hour',y='Total_sales',data=market,showmeans=True)
plt.title("busiest hour of the day")
# Out:
# Text(0.5, 1.0, 'busiest hour of the day')

# %% [markdown]
# #### Result:- from the baove graph it is clear that, afternoon 2 pm is the busiest hour of the day.

# %% [markdown]
# ### Q 10) Which product line should your supermarket focus on?

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='Product line',y='Total_sales',data=market,showmeans=True)
plt.title("target product line to increase profit")
# Out:
# Text(0.5, 1.0, 'target product line to increase profit')

# %% [markdown]
# #### Result:- based on this graph , it is clear that the superstore should focus on "home & lifestyle"

# %% [markdown]
# ### Q 11)Which city should be chosen for expansion and what products should be focussed on?

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="Product line",y="City",data=market,hue="Total_sales")
plt.xlabel("City")
plt.ylabel("product line")
plt.title("relationship between city & Product line")
# Out:
# Text(0.5, 1.0, 'relationship between city & Product line')

# %% [markdown]
# #### Result:- based on above graph, city ("mandalay")should be chosen for expansion, and ("sports & travel" AND "home & lifestyle")should be product categories to be focussed on.
